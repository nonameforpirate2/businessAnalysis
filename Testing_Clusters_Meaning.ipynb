# %%
import pandas as pd
import numpy as np
import nltk 
from nltk import pos_tag
import re
import itertools
from apriori_python import apriori

clusters30 = pd.read_csv('clusters_30.csv')
clusters25 = pd.read_csv('clusters25.csv')
clusters20 = pd.read_csv('clusters_20.csv')

# %%
def get_clust_description(df):
    clust = np.transpose(df['cluster'].value_counts().index)
    freq = np.transpose(np.array(df['cluster'].value_counts()))
    df_freq = pd.DataFrame({"cluster" : clust, "frequency" : freq}).sort_values(by = ['frequency'], ascending=False)
    df_freq['percent'] = df_freq['frequency'] / df_freq['frequency'].sum() * 100
    df_freq_ = df_freq.head(10)
    df_freq_['percent_sum_top_n'] = df_freq_['percent'].sum()
    return df_freq_

# %%
def get_tokenize_noun(text):
    text_clean = text.split(', ')
    texts = []
    filters = ['NN','NNS','NNP']
    nouns = []
    for element in text_clean:
        if element is not '':
            texts.append(re.sub('[^a-zA-Z]+','',element))
    try:
        pos_texts = pos_tag(texts)
        for element in pos_texts:
            if element[1] in filters:
                nouns.append(element[0])
    except:
        nouns.append('noNoun')
    return nouns

# %%
def get_tokenize_adj(text):
    text_clean = text.split(', ')
    texts = []
    filters = ['JJ','JJR','JJS']
    adj = []
    for element in text_clean:
        if element is not '':
            texts.append(re.sub('[^a-zA-Z]+','',element))
    try:
        pos_texts = pos_tag(texts)
        for element in pos_texts:
            if element[1] in filters:
                adj.append(element[0])
    except:
        adj.append('noAdj')
    return adj

# %%
def create_adj_nouns(df):
    df['tokenize_adj'] = list(map(get_tokenize_adj,df['text']))
    df['tokenize_noun'] = list(map(get_tokenize_noun,df['text']))
    return df

# %%
def get_dict_desc_top(pandas_column,n):
    noun_adj = list(itertools.chain(*pandas_column))
    noun_adj = pd.DataFrame({'adj': noun_adj})
    noun_adj = pd.DataFrame(noun_adj['adj'].value_counts())
    noun_adj = noun_adj.reset_index()
    noun_adj_dict = dict(noun_adj.head(n).values)
    return noun_adj_dict

# %%
def get_clust_desc(df):
    noun = get_dict_desc_top(df['tokenize_noun'],20)
    adj = get_dict_desc_top(df['tokenize_adj'],20)
    return noun, adj

# %%
def get_tokens(text):
    try:
        tokens = text.split(' ')
    except:
        tokens = 'no, Object'
    return tokens

# %%
def get_rules_properties(rules):
    df = pd.DataFrame(rules)
    df = df[df[2] != 1.0]
    df = df.sort_values(by = [2], ascending=False)
    return df

# %%
def get_cluster_properties(cluster_df, n_cluster, min_sup, min_conf):
    df = cluster_df[cluster_df['cluster']==n_cluster]
    df = create_adj_nouns(df)
    df['tokens'] = list(map(get_tokens,df['tokens']))
    df_noun, df_adj = get_clust_desc(df)
    freqItems, rules = apriori(df['tokens'], minSup=min_sup, minConf=min_conf)
    try:
        rules_df = get_rules_properties(rules)
    except:
        rules_df = 'no rules found'
    return df_noun, df_adj, df, rules_df

# %%
clust20 = get_clust_description(clusters20)
clust20
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    cluster  frequency    percent  percent_sum_top_n
# 0       12      58755  10.842226           72.22172
# 1        1      52684   9.721927           72.22172
# 2       19      42086   7.766249           72.22172
# 3        6      40380   7.451436           72.22172
# 4        8      36250   6.689315           72.22172
# 5        7      34886   6.437612           72.22172
# 6        3      34768   6.415837           72.22172
# 7       16      33066   6.101762           72.22172
# 8       11      31932   5.892502           72.22172
# 9       13      26569   4.902853           72.22172

# %%
noun20_12, adj20_12, clust20_12, rules20_12_df = get_cluster_properties(clusters20,12,0.02,0.02)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
rules20_12_df
# Out:
#                     0                      1         2
# 20             {reel}               {ribbon}  0.998580
# 19             {doll}            {feltcraft}  0.967914
# 18             {herb}               {marker}  0.868217
# 17             {rack}                 {coat}  0.839111
# 16           {marker}                 {herb}  0.798246
# 15            {block}       {building, word}  0.765892
# 14            {block}             {building}  0.765892
# 13            {block}                 {word}  0.765892
# 12             {rose}              {english}  0.670244
# 11              {key}                  {fob}  0.598909
# 10            {cover}              {cushion}  0.585131
# 9            {ribbon}                 {reel}  0.556611
# 8           {cushion}                {cover}  0.554926
# 7   {feltcraft, doll}             {princess}  0.548803
# 6              {doll}  {feltcraft, princess}  0.531194
# 5              {doll}             {princess}  0.531194
# 4         {feltcraft}                 {doll}  0.455060
# 3           {cushion}            {feltcraft}  0.391564
# 2         {feltcraft}              {cushion}  0.260633
# 1         {feltcraft}       {princess, doll}  0.249738
# 0         {feltcraft}             {princess}  0.249738

# %%
noun20_12
# Out:
# {'feltcraft': 4773,
#  'cushion': 3177,
#  'cover': 3013,
#  'ribbon': 2526,
#  'block': 2281,
#  'pink': 2250,
#  'doll': 2244,
#  'postage': 1961,
#  'marker': 1824,
#  'garden': 1817,
#  'word': 1747,
#  'building': 1747,
#  'flower': 1729,
#  'herb': 1677,
#  'home': 1662,
#  'rack': 1529,
#  'nan': 1454,
#  'reel': 1408,
#  'doormat': 1391,
#  'mat': 1376}

# %%
adj20_12
# Out:
# {'key': 2017,
#  'doormat': 1707,
#  'black': 1660,
#  'edwardian': 1216,
#  'blue': 1184,
#  'poppy': 1050,
#  'wooden': 781,
#  'new': 697,
#  'white': 649,
#  'magic': 617,
#  'purple': 615,
#  'green': 574,
#  'manual': 572,
#  'natural': 558,
#  'decorative': 507,
#  'bundle': 500,
#  'french': 464,
#  'garden': 464,
#  'floral': 424,
#  'yellow': 348}

# %%
noun20_1, adj20_1, clust20_1, rules20_1_df = get_cluster_properties(clusters20,1,0.05,0.05)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
rules20_1_df
# Out:
#                    0                 1         2
# 55        {woodland}             {bag}  0.967963
# 54            {pink}             {bag}  0.958996
# 53           {skull}             {bag}  0.951664
# 52           {apple}             {bag}  0.946364
# 51           {lunch}             {bag}  0.937215
# 50            {suki}             {bag}  0.915010
# 49           {jumbo}             {bag}  0.897393
# 48         {vintage}             {bag}  0.845494
# 47        {bag, red}       {retrospot}  0.818197
# 46             {red}             {bag}  0.809971
# 44       {retrospot}        {bag, red}  0.806666
# 43       {retrospot}             {red}  0.806666
# 45  {bag, retrospot}             {red}  0.806666
# 42  {jumbo, vintage}             {bag}  0.732354
# 41             {red}  {bag, retrospot}  0.662716
# 40             {red}       {retrospot}  0.662716
# 39         {paisley}             {bag}  0.643205
# 38       {pink, bag}        {polkadot}  0.617923
# 37     {bag, design}           {lunch}  0.608687
# 36          {design}      {lunch, bag}  0.608687
# 35          {design}           {lunch}  0.608687
# 34            {pink}   {polkadot, bag}  0.592586
# 33            {pink}        {polkadot}  0.592586
# 32         {paisley}           {jumbo}  0.548463
# 31         {paisley}         {vintage}  0.515706
# 30         {vintage}           {jumbo}  0.513609
# 29             {red}           {jumbo}  0.494483
# 28    {bag, vintage}           {jumbo}  0.444880
# 27      {lunch, bag}          {design}  0.420648
# 26             {bag}           {jumbo}  0.396796
# 25           {lunch}     {bag, design}  0.394238
# 24           {lunch}          {design}  0.394238
# 23         {vintage}      {bag, jumbo}  0.376144
# 22         {vintage}         {paisley}  0.351098
# 21             {bag}           {lunch}  0.288508
# 20           {jumbo}         {vintage}  0.212451
# 19             {bag}          {design}  0.199381
# 18      {bag, jumbo}         {vintage}  0.173379
# 17           {jumbo}             {red}  0.171721
# 16           {jumbo}    {bag, vintage}  0.155589
# 15             {bag}         {vintage}  0.154639
# 14           {jumbo}         {paisley}  0.154454
# 13             {bag}       {retrospot}  0.126150
# 12             {bag}             {red}  0.124372
# 11             {bag}       {charlotte}  0.123034
# 10             {bag}   {lunch, design}  0.121360
# 9              {bag}            {pink}  0.107137
# 8              {bag}  {red, retrospot}  0.101761
# 7              {bag}            {suki}  0.083773
# 6              {bag}         {paisley}  0.080091
# 5              {bag}  {jumbo, vintage}  0.068796
# 4              {bag}  {pink, polkadot}  0.066202
# 3              {bag}        {polkadot}  0.066202
# 2              {bag}           {apple}  0.065324
# 1              {bag}        {woodland}  0.065094
# 0              {bag}           {skull}  0.056831

# %%
noun20_1
# Out:
# {'bag': 47808,
#  'lunch': 14717,
#  'design': 9532,
#  'vintage': 8744,
#  'retrospot': 6031,
#  'paisley': 5953,
#  'charlotte': 5882,
#  'suki': 3845,
#  'apple': 3300,
#  'woodland': 3215,
#  'polkadot': 3165,
#  'pink': 2968,
#  'spaceboy': 2818,
#  'skull': 2442,
#  'strawberry': 2271,
#  'alphabet': 2190,
#  'blue': 2028,
#  'storage': 1934,
#  'leaf': 1624,
#  'shoulder': 1610}

# %%
adj20_1
# Out:
# {'jumbo': 21139,
#  'black': 2310,
#  'red': 1745,
#  'girl': 1585,
#  'scandinavian': 1320,
#  'shopper': 1202,
#  'white': 1086,
#  'marble': 702,
#  'floral': 661,
#  'suki': 532,
#  'skull': 413,
#  'blue': 363,
#  'cosmetic': 189,
#  'overnight': 186,
#  'save': 177,
#  'soft': 103,
#  'brown': 97,
#  'grey': 84,
#  'circular': 60,
#  'lolita': 55}

# %%
noun20_19, adj20_19, clust20_19, rules20_19_df = get_cluster_properties(clusters20,19,0.05,0.05)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun20_19
# Out:
# {'heart': 27228,
#  'decoration': 8322,
#  'wicker': 7032,
#  'ivory': 2693,
#  'bell': 2466,
#  'chalkboard': 2218,
#  'zinc': 2188,
#  'star': 2026,
#  'butterfly': 1708,
#  'mirror': 1587,
#  'pot': 1403,
#  'wood': 1364,
#  'pink': 1356,
#  'trinket': 1269,
#  'hanging': 1148,
#  'bird': 1127,
#  'basket': 1110,
#  'slate': 1104,
#  'wreath': 965,
#  'picnic': 943}

# %%
adj20_19
# Out:
# {'small': 6470,
#  'large': 6089,
#  'white': 4045,
#  'natural': 2643,
#  'slate': 1280,
#  'metal': 1113,
#  'red': 1028,
#  'crystal': 777,
#  'decorative': 608,
#  'doormat': 599,
#  'green': 565,
#  'cream': 536,
#  'rustic': 533,
#  'ivory': 487,
#  'sleigh': 476,
#  'hottie': 449,
#  'gingham': 427,
#  'single': 390,
#  'filigree': 347,
#  'zinc': 317}

# %%
rules20_19_df
# Out:
#                    0                      1         2
# 37  {slate, natural}           {chalkboard}  0.930369
# 36           {slate}  {natural, chalkboard}  0.930369
# 35           {slate}           {chalkboard}  0.930369
# 34         {natural}                {slate}  0.902005
# 33         {natural}    {slate, chalkboard}  0.839198
# 32         {natural}           {chalkboard}  0.839198
# 31   {small, wicker}                {heart}  0.780772
# 30   {large, wicker}                {heart}  0.746827
# 29           {white}                {heart}  0.724598
# 28           {ivory}                {heart}  0.718239
# 27          {wicker}                {heart}  0.708760
# 26           {small}                {heart}  0.707264
# 25      {decoration}                {heart}  0.612233
# 24           {large}                {heart}  0.594515
# 23    {heart, large}               {wicker}  0.585083
# 22    {heart, small}               {wicker}  0.468531
# 21           {large}               {wicker}  0.465758
# 20         {hanging}                {heart}  0.443729
# 19   {heart, wicker}                {small}  0.430177
# 18   {heart, wicker}                {large}  0.424960
# 17           {small}               {wicker}  0.424420
# 16         {hanging}           {decoration}  0.421930
# 15          {wicker}                {large}  0.403299
# 14          {wicker}                {small}  0.390501
# 13      {decoration}              {hanging}  0.386085
# 12           {large}        {heart, wicker}  0.347840
# 11           {small}        {heart, wicker}  0.331376
# 10          {wicker}         {heart, small}  0.304892
# 9           {wicker}         {heart, large}  0.301195
# 8            {heart}           {decoration}  0.187124
# 7            {heart}               {wicker}  0.183047
# 6            {heart}                {small}  0.168062
# 5            {heart}                {large}  0.132951
# 4            {heart}              {hanging}  0.124100
# 3            {heart}                {white}  0.107647
# 2            {heart}                {ivory}  0.083884
# 1            {heart}        {small, wicker}  0.078742
# 0            {heart}        {large, wicker}  0.077788

# %%
noun20_6, adj20_6, clust20_6, rules20_6_df = get_cluster_properties(clusters20,6,0.05,0.05)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun20_6
# Out:
# {'tin': 14350,
#  'design': 11550,
#  'pantry': 6212,
#  'mug': 4993,
#  'vintage': 4555,
#  'plaster': 3733,
#  'cake': 3580,
#  'childrens': 3559,
#  'spaceboy': 2519,
#  'coffee': 2221,
#  'pack': 1921,
#  'wrap': 1898,
#  'london': 1601,
#  'apple': 1396,
#  'circus': 1373,
#  'biscuit': 1249,
#  'knack': 1243,
#  'mini': 1160,
#  'tea': 1156,
#  'parade': 1155}

# %%
adj20_6
# Out:
# {'girl': 4955,
#  'knick': 1243,
#  'magnetic': 1071,
#  'magic': 884,
#  'spaceboy': 776,
#  'napkin': 709,
#  'green': 524,
#  'tea': 509,
#  'ceramic': 463,
#  'skull': 413,
#  'save': 374,
#  'poppy': 355,
#  'tonic': 304,
#  'queen': 279,
#  'cat': 270,
#  'boy': 247,
#  'doormat': 235,
#  'lola': 219,
#  'mitt': 218,
#  'slate': 203}

# %%
rules20_6_df
# Out:
#                         0                      1         2
# 62                {dolly}                 {girl}  0.985029
# 61          {set, design}               {pantry}  0.977639
# 60            {tin, cake}                  {set}  0.923182
# 59                 {girl}                {dolly}  0.907997
# 58          {tin, design}          {pantry, set}  0.860764
# 57          {tin, design}               {pantry}  0.860764
# 56          {tin, design}                  {set}  0.860764
# 55          {pantry, set}               {design}  0.853820
# 54     {pantry, tin, set}               {design}  0.821529
# 53          {pantry, tin}          {set, design}  0.821529
# 52          {pantry, tin}               {design}  0.821529
# 51          {pantry, set}                  {tin}  0.819070
# 50                 {cake}                  {tin}  0.814525
# 49  {pantry, set, design}                  {tin}  0.788093
# 47          {set, design}                  {tin}  0.770470
# 48          {set, design}          {pantry, tin}  0.770470
# 46       {pantry, design}                  {set}  0.770008
# 45                  {set}                  {tin}  0.761152
# 44                 {cake}             {tin, set}  0.751955
# 43                 {cake}                  {set}  0.751955
# 42          {pantry, set}          {tin, design}  0.672889
# 41               {pantry}               {design}  0.621539
# 40       {pantry, design}             {tin, set}  0.606838
# 39       {pantry, design}                  {tin}  0.606838
# 38                 {cake}               {design}  0.596927
# 37               {pantry}                  {set}  0.560528
# 36              {vintage}                  {tin}  0.535236
# 35             {tin, set}               {pantry}  0.481675
# 34               {pantry}          {set, design}  0.478590
# 32               {pantry}                  {tin}  0.459111
# ..                    ...                    ...       ...
# 29                  {tin}                  {set}  0.412613
# 28             {tin, set}       {pantry, design}  0.395710
# 27             {tin, set}               {design}  0.395710
# 26                  {set}               {design}  0.390924
# 25                  {set}       {pantry, design}  0.382183
# 24               {pantry}     {tin, set, design}  0.377173
# 23               {pantry}          {tin, design}  0.377173
# 22                  {set}          {pantry, tin}  0.366628
# 21                  {set}            {tin, cake}  0.346060
# 20                  {set}                 {cake}  0.346060
# 19               {design}               {pantry}  0.334286
# 17                  {set}          {tin, design}  0.301196
# 18                  {set}  {pantry, design, tin}  0.301196
# 16               {design}                  {set}  0.263290
# 15                  {tin}              {plaster}  0.260139
# 14               {design}          {pantry, set}  0.257403
# 13               {design}                  {tin}  0.235671
# 12                  {tin}                 {cake}  0.203206
# 11               {design}     {pantry, set, tin}  0.202857
# 10               {design}          {pantry, tin}  0.202857
# 9                {design}             {tin, set}  0.202857
# 8                   {tin}          {pantry, set}  0.198746
# 7                   {tin}               {pantry}  0.198746
# 6                   {tin}               {design}  0.189686
# 5                   {tin}            {set, cake}  0.187596
# 4                {design}                 {cake}  0.185022
# 3                   {tin}              {vintage}  0.169895
# 2                   {tin}  {pantry, set, design}  0.163275
# 1                   {tin}       {pantry, design}  0.163275
# 0                   {tin}          {set, design}  0.163275
#
# [63 rows x 3 columns]

# %%
noun20_8, adj20_8, clust20_8, rules20_8_df = get_cluster_properties(clusters20,8,0.05,0.05)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun20_8
# Out:
# {'christmas': 15635,
#  'decoration': 5968,
#  'light': 3690,
#  'ribbon': 3373,
#  'star': 3321,
#  'tree': 3012,
#  'garland': 2746,
#  'heart': 2569,
#  'vintage': 1967,
#  'craft': 1917,
#  'bell': 1455,
#  'scandinavian': 1443,
#  'wrap': 1264,
#  'rabbit': 1260,
#  'wooden': 1236,
#  'sticker': 1203,
#  'roll': 1201,
#  'night': 1051,
#  'charm': 1021,
#  'top': 971}

# %%
adj20_8
# Out:
# {'wooden': 4486,
#  'traditional': 3519,
#  'white': 1344,
#  'happy': 1065,
#  'rustic': 986,
#  'tree': 884,
#  'light': 684,
#  'green': 651,
#  'd': 635,
#  'little': 565,
#  'red': 496,
#  'table': 486,
#  'angel': 402,
#  'magic': 376,
#  'bunny': 371,
#  'bauble': 355,
#  'giant': 346,
#  'lantern': 341,
#  'sleigh': 318,
#  'wish': 274}

# %%
rules20_8_df
# Out:
#                0             1         2
# 11        {tree}   {christmas}  0.651065
# 10        {star}   {christmas}  0.649763
# 9       {ribbon}   {christmas}  0.566854
# 8   {decoration}      {wooden}  0.394605
# 7       {wooden}  {decoration}  0.333003
# 6   {decoration}   {christmas}  0.319370
# 5       {wooden}   {christmas}  0.292845
# 4    {christmas}        {tree}  0.194716
# 3    {christmas}        {star}  0.138155
# 2    {christmas}      {wooden}  0.130588
# 1    {christmas}      {ribbon}  0.120562
# 0    {christmas}  {decoration}  0.120184

# %%
noun20_13, adj20_13, clust20_13, rules20_13_df = get_cluster_properties(clusters20,13,0.05,0.05)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun20_13
# Out:
# {'box': 24398,
#  'lunch': 2927,
#  'trinket': 2810,
#  'recipe': 2570,
#  'book': 2196,
#  'design': 1970,
#  'cutlery': 1876,
#  'snack': 1721,
#  'round': 1690,
#  'tissue': 1573,
#  'retrospot': 1521,
#  'pink': 1439,
#  'gingham': 1372,
#  'harmonica': 1291,
#  'pack': 1230,
#  'pantry': 1180,
#  'craft': 1171,
#  'woodland': 1166,
#  'blue': 1153,
#  'vintage': 1093}

# %%
adj20_13
# Out:
# {'red': 1877,
#  'ceramic': 1648,
#  'yellow': 1400,
#  'victorian': 943,
#  'strawberry': 770,
#  'small': 697,
#  'wooden': 620,
#  'blue': 620,
#  'sweetheart': 543,
#  'green': 467,
#  'bundle': 359,
#  'candle': 291,
#  'large': 287,
#  'abc': 239,
#  'pen': 223,
#  'gymkhana': 215,
#  'ocean': 207,
#  'picnic': 203,
#  'swallow': 166,
#  'cosy': 159}

# %%
rules20_13_df
# Out:
#                     0                    1         2
# 71              {set}                {box}  0.995775
# 70  {round, set, box}              {snack}  0.994675
# 69       {set, round}         {box, snack}  0.994675
# 68       {set, round}              {snack}  0.994675
# 64            {snack}         {set, round}  0.976758
# 61            {snack}                {set}  0.976758
# 62            {snack}              {round}  0.976758
# 63            {snack}                {box}  0.976758
# 65            {snack}         {round, box}  0.976758
# 66            {snack}           {set, box}  0.976758
# 67            {snack}    {set, round, box}  0.976758
# 60              {red}                {box}  0.973559
# 59          {trinket}                {box}  0.963701
# 58       {round, box}                {set}  0.963512
# 57            {round}           {set, box}  0.963512
# 56            {round}                {set}  0.963512
# 52            {round}         {box, snack}  0.958381
# 50            {round}              {snack}  0.958381
# 51            {round}         {set, snack}  0.958381
# 55       {round, box}         {set, snack}  0.958381
# 53       {round, box}              {snack}  0.958381
# 54            {round}    {set, box, snack}  0.958381
# 49       {strawberry}                {box}  0.955627
# 48     {box, cutlery}              {lunch}  0.941365
# 47          {cutlery}         {lunch, box}  0.941365
# 46          {cutlery}              {lunch}  0.941365
# 45             {rose}                {box}  0.880152
# 44          {ceramic}                {box}  0.868325
# 43           {recipe}                {box}  0.854086
# 42          {ceramic}            {trinket}  0.838592
# ..                ...                  ...       ...
# 29      {recipe, box}             {design}  0.706606
# 28             {book}                {box}  0.609745
# 27           {recipe}        {design, box}  0.603502
# 26           {recipe}             {design}  0.603502
# 25       {lunch, box}            {cutlery}  0.603348
# 24            {lunch}       {box, cutlery}  0.603348
# 23            {lunch}            {cutlery}  0.603348
# 22          {trinket}            {ceramic}  0.491815
# 21              {box}              {lunch}  0.119694
# 20              {box}            {trinket}  0.110739
# 19              {box}                {set}  0.096385
# 18              {box}             {recipe}  0.089760
# 17              {box}             {design}  0.080559
# 16              {box}            {cutlery}  0.076715
# 15              {box}                {red}  0.075284
# 14              {box}               {blue}  0.072503
# 13              {box}     {lunch, cutlery}  0.072217
# 12              {box}              {round}  0.071727
# 11              {box}         {set, round}  0.069109
# 10              {box}  {set, round, snack}  0.068741
# 9               {box}         {set, snack}  0.068741
# 8               {box}       {round, snack}  0.068741
# 7               {box}              {snack}  0.068741
# 6               {box}     {recipe, design}  0.063425
# 5               {box}          {retrospot}  0.062198
# 4               {box}         {strawberry}  0.060767
# 3               {box}               {pink}  0.058968
# 2               {box}            {ceramic}  0.058518
# 1               {box}               {rose}  0.056760
# 0               {box}               {book}  0.054756
#
# [72 rows x 3 columns]

# %%
clust25 = get_clust_description(clusters25)
clust25
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    cluster  frequency   percent  percent_sum_top_n
# 0       24      46460  8.573395          56.505059
# 1        3      35426  6.537260          56.505059
# 2       13      34293  6.328184          56.505059
# 3       11      33769  6.231489          56.505059
# 4        9      31149  5.748013          56.505059
# 5       22      29412  5.427480          56.505059
# 6        2      26854  4.955445          56.505059
# 7       21      24302  4.484517          56.505059
# 8       23      22454  4.143500          56.505059
# 9       14      22087  4.075777          56.505059

# %%
noun25_24, adj25_24, clust25_24, rules25_24_df = get_cluster_properties(clusters25,24,0.05,0.05)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun25_24
# Out:
# {'bag': 39656,
#  'lunch': 15699,
#  'design': 9532,
#  'vintage': 7493,
#  'charlotte': 4814,
#  'paisley': 4652,
#  'suki': 3845,
#  'box': 3545,
#  'woodland': 3215,
#  'polkadot': 3165,
#  'apple': 3123,
#  'strawberry': 2869,
#  'spaceboy': 2818,
#  'pink': 2749,
#  'skull': 2715,
#  'alphabet': 2190,
#  'storage': 1934,
#  'blue': 1872,
#  'cutlery': 1740,
#  'leaf': 1624}

# %%
adj25_24
# Out:
# {'jumbo': 18980,
#  'girl': 2578,
#  'black': 2310,
#  'scandinavian': 1280,
#  'shopper': 1202,
#  'white': 960,
#  'marble': 702,
#  'suki': 532,
#  'skull': 413,
#  'blue': 257,
#  'save': 177,
#  'red': 134,
#  'soft': 103,
#  'modern': 99,
#  'circular': 60,
#  'lolita': 55,
#  'du': 53,
#  'sud': 53,
#  'cosmetic': 53,
#  'metalic': 37}

# %%
rules25_24_df
# Out:
#                    0                 1         2
# 43            {girl}           {dolly}  0.995330
# 42        {woodland}             {bag}  0.967963
# 41            {suki}             {bag}  0.915010
# 40           {jumbo}             {bag}  0.885722
# 39         {vintage}             {bag}  0.827439
# 38           {skull}             {bag}  0.819373
# 37           {lunch}             {bag}  0.774189
# 36         {paisley}             {bag}  0.734738
# 35  {jumbo, vintage}             {bag}  0.732354
# 34         {paisley}           {jumbo}  0.701849
# 33       {pink, bag}        {polkadot}  0.678748
# 32            {pink}   {polkadot, bag}  0.678748
# 31            {pink}        {polkadot}  0.678748
# 30     {bag, design}           {lunch}  0.608687
# 29          {design}      {lunch, bag}  0.608687
# 28          {design}           {lunch}  0.608687
# 27         {vintage}           {jumbo}  0.599359
# 26         {paisley}         {vintage}  0.539983
# 25    {bag, vintage}           {jumbo}  0.530484
# 24      {lunch, bag}          {design}  0.477374
# 23         {vintage}      {bag, jumbo}  0.438943
# 22             {bag}           {jumbo}  0.423921
# 21           {lunch}     {bag, design}  0.369578
# 20           {lunch}          {design}  0.369578
# 19         {vintage}         {paisley}  0.335246
# 18             {bag}           {lunch}  0.306486
# 17             {bag}          {design}  0.240367
# 16           {jumbo}         {vintage}  0.236617
# 15           {lunch}             {box}  0.225811
# 14      {bag, jumbo}         {vintage}  0.195646
# 13           {jumbo}    {bag, vintage}  0.173288
# 12           {jumbo}         {paisley}  0.172023
# 11             {bag}         {vintage}  0.156345
# 10             {bag}   {lunch, design}  0.146308
# 9              {bag}       {charlotte}  0.121394
# 8              {bag}            {pink}  0.117586
# 7              {bag}            {suki}  0.100994
# 6              {bag}         {paisley}  0.086191
# 5              {bag}  {jumbo, vintage}  0.082938
# 4              {bag}  {pink, polkadot}  0.079811
# 3              {bag}        {polkadot}  0.079811
# 2              {bag}           {apple}  0.078752
# 1              {bag}        {woodland}  0.078475
# 0              {bag}           {skull}  0.064631

# %%
noun25_3, adj25_3, clust25_3, rules25_3_df = get_cluster_properties(clusters25,3,0.05,0.05)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun25_3
# Out:
# {'paper': 8366,
#  'set': 7490,
#  'christmas': 4000,
#  'chain': 3420,
#  'vintage': 3094,
#  'jam': 2663,
#  'retrospot': 2650,
#  'cutter': 2575,
#  'heart': 2554,
#  'making': 2411,
#  'cookie': 2335,
#  'piece': 1666,
#  'jar': 1481,
#  'sticker': 1328,
#  'tlights': 1208,
#  'magnet': 1132,
#  'stationery': 1071,
#  'gift': 1053,
#  'napkin': 1022,
#  'kid': 1000}

# %%
adj25_3
# Out:
# {'white': 939,
#  'traditional': 895,
#  'kit': 850,
#  'floral': 821,
#  'lantern': 713,
#  'd': 669,
#  'light': 629,
#  'napkin': 534,
#  'pink': 515,
#  'black': 487,
#  'retrospot': 462,
#  'soldier': 455,
#  'skittle': 455,
#  'collage': 408,
#  'modern': 376,
#  'colour': 376,
#  'retro': 367,
#  'teatime': 339,
#  'girl': 283,
#  'lucky': 260}

# %%
rules25_3_df
# Out:
#                       0                          1         2
# 57              {chain}               {paper, kit}  0.971930
# 56              {chain}                      {kit}  0.971930
# 55              {chain}                    {paper}  0.971930
# 54              {heart}                      {set}  0.951449
# 53        {cutter, set}                   {cookie}  0.906796
# 52             {cutter}              {cookie, set}  0.906796
# 51             {cutter}                   {cookie}  0.906796
# 50           {set, jam}                   {making}  0.905370
# 49                {jam}              {making, set}  0.905370
# 48                {jam}                   {making}  0.905370
# 45                {kit}                    {chain}  0.825633
# 47                {kit}             {paper, chain}  0.825633
# 46                {kit}                    {paper}  0.825633
# 44          {retrospot}                      {set}  0.801093
# 43            {vintage}                      {set}  0.725275
# 42            {vintage}                {christmas}  0.626697
# 41  {paper, kit, chain}                {christmas}  0.619735
# 40         {paper, kit}         {christmas, chain}  0.619735
# 39         {kit, chain}         {paper, christmas}  0.619735
# 38       {paper, chain}           {kit, christmas}  0.619735
# 37         {paper, kit}                {christmas}  0.619735
# 36         {kit, chain}                {christmas}  0.619735
# 35       {paper, chain}                {christmas}  0.619735
# 34              {chain}    {paper, kit, christmas}  0.602339
# 33              {chain}           {kit, christmas}  0.602339
# 32              {chain}         {paper, christmas}  0.602339
# 31              {chain}                {christmas}  0.602339
# 30                {kit}  {paper, christmas, chain}  0.511674
# 29                {kit}         {paper, christmas}  0.511674
# 28                {kit}         {christmas, chain}  0.511674
# 27                {kit}                {christmas}  0.511674
# 26          {christmas}        {paper, kit, chain}  0.494717
# 25          {christmas}               {paper, kit}  0.494717
# 24          {christmas}               {kit, chain}  0.494717
# 23          {christmas}             {paper, chain}  0.494717
# 22          {christmas}                      {kit}  0.494717
# 21          {christmas}                    {paper}  0.494717
# 20          {christmas}                    {chain}  0.494717
# 19          {christmas}                  {vintage}  0.465658
# 16              {paper}                    {chain}  0.408203
# 18              {paper}               {kit, chain}  0.408203
# 17              {paper}                      {kit}  0.408203
# 15              {paper}                      {set}  0.316714
# 14              {paper}    {kit, christmas, chain}  0.252978
# 13              {paper}           {kit, christmas}  0.252978
# 12              {paper}         {christmas, chain}  0.252978
# 11              {paper}                {christmas}  0.252978
# 10                {set}                      {jam}  0.096717
# 9                 {set}                    {paper}  0.093666
# 8                 {set}                   {cutter}  0.093521
# 7                 {set}                {retrospot}  0.090543
# 6                 {set}                    {heart}  0.088255
# 5                 {set}              {making, jam}  0.087564
# 4                 {set}                   {making}  0.087564
# 2                 {set}                   {cookie}  0.084804
# 3                 {set}           {cookie, cutter}  0.084804
# 1                 {set}                  {vintage}  0.081499
# 0                 {set}                    {doily}  0.080410

# %%
noun25_13, adj25_13, clust25_13, rules25_13_df = get_cluster_properties(clusters25,13,0.05,0.05)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun25_13
# Out:
# {'heart': 19945,
#  'wicker': 5995,
#  'ivory': 2947,
#  'photo': 2848,
#  'chalkboard': 2218,
#  'frame': 2142,
#  'hook': 1977,
#  'butterfly': 1640,
#  'sweetheart': 1611,
#  'mirror': 1566,
#  'pink': 1559,
#  'cream': 1326,
#  'wood': 1320,
#  'egg': 1300,
#  'mini': 1290,
#  'wire': 1183,
#  'slate': 1104,
#  'shape': 1037,
#  'hanging': 888,
#  'antique': 886}

# %%
adj25_13
# Out:
# {'small': 5676,
#  'large': 5598,
#  'white': 5018,
#  'natural': 2712,
#  'red': 1602,
#  'slate': 1280,
#  'crystal': 745,
#  'ivory': 702,
#  'decorative': 614,
#  'doormat': 599,
#  'hottie': 449,
#  'magic': 409,
#  'single': 390,
#  'classic': 381,
#  'antique': 379,
#  'filigree': 346,
#  'green': 324,
#  'triple': 313,
#  'victorian': 294,
#  'cupid': 293}

# %%
rules25_13_df
# Out:
#                    0                      1         2
# 39   {small, wicker}                {heart}  0.944910
# 38   {large, wicker}                {heart}  0.930580
# 37  {slate, natural}           {chalkboard}  0.930369
# 36           {slate}  {natural, chalkboard}  0.930369
# 35           {slate}           {chalkboard}  0.930369
# 34           {frame}                {photo}  0.891690
# 33         {natural}                {slate}  0.879056
# 32            {love}                {heart}  0.860417
# 31          {wicker}                {heart}  0.831359
# 30             {red}                {heart}  0.825740
# 29         {natural}    {slate, chalkboard}  0.817847
# 28         {natural}           {chalkboard}  0.817847
# 27            {pink}                {heart}  0.766568
# 26           {small}                {heart}  0.728858
# 25           {photo}                {frame}  0.670646
# 24           {large}                {heart}  0.646660
# 23           {ivory}                {heart}  0.625925
# 22           {white}                {heart}  0.595058
# 21    {heart, large}               {wicker}  0.585083
# 20    {heart, small}               {wicker}  0.518250
# 19   {heart, wicker}                {small}  0.430177
# 18   {heart, wicker}                {large}  0.424960
# 17           {large}               {wicker}  0.406574
# 16           {small}               {wicker}  0.399753
# 15          {wicker}                {large}  0.379650
# 14          {wicker}                {small}  0.378482
# 13           {large}        {heart, wicker}  0.378349
# 12           {small}        {heart, wicker}  0.377731
# 11          {wicker}         {heart, small}  0.357631
# 10          {wicker}         {heart, large}  0.353294
# 9            {heart}               {wicker}  0.249887
# 8            {heart}                {small}  0.207420
# 7            {heart}                {large}  0.181499
# 6            {heart}                {white}  0.149712
# 5            {heart}                {ivory}  0.114515
# 4            {heart}        {small, wicker}  0.107496
# 3            {heart}        {large, wicker}  0.106192
# 2            {heart}                 {love}  0.103535
# 1            {heart}                 {pink}  0.091050
# 0            {heart}                  {red}  0.088142

# %%
clust30 = get_clust_description(clusters30)
clust30
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    cluster  frequency   percent  percent_sum_top_n
# 0        3      36516  6.738401          54.258741
# 1        2      36044  6.651301          54.258741
# 2        1      35259  6.506443          54.258741
# 3       12      30822  5.687671          54.258741
# 4        7      30338  5.598357          54.258741
# 5        9      27509  5.076314          54.258741
# 6        0      25698  4.742125          54.258741
# 7        4      25680  4.738803          54.258741
# 8       20      23476  4.332093          54.258741
# 9       10      22691  4.187234          54.258741

# %%
noun30_3, adj30_3, clust30_3, rules30_3_df = get_cluster_properties(clusters30,3,0.025,0.025)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun30_3
# Out:
# {'ribbon': 4693,
#  'reel': 2346,
#  'postage': 1961,
#  'rack': 1548,
#  'notebook': 1504,
#  'nan': 1454,
#  'pink': 1286,
#  'coat': 1283,
#  'charm': 1272,
#  'block': 1190,
#  'magnet': 1186,
#  'letter': 1172,
#  'ring': 1164,
#  'fob': 1069,
#  'babushka': 1010,
#  'parasol': 1009,
#  'tray': 910,
#  'heart': 905,
#  'purse': 855,
#  'gumball': 842}

# %%
adj30_3
# Out:
# {'key': 2116,
#  'black': 1797,
#  'edwardian': 1216,
#  'rustic': 995,
#  'purple': 721,
#  'white': 677,
#  'yellow': 628,
#  'traditional': 622,
#  'blue': 620,
#  'small': 607,
#  'manual': 572,
#  'decorative': 569,
#  'natural': 558,
#  'wooden': 534,
#  'red': 454,
#  'large': 410,
#  'acrylic': 344,
#  'grand': 303,
#  'brown': 300,
#  'snowy': 283}

# %%
rules30_3_df
# Out:
#               0                 1         2
# 16       {reel}          {ribbon}  0.999254
# 15     {rustic}   {ribbon, charm}  0.990955
# 14     {rustic}          {ribbon}  0.990955
# 13     {rustic}           {charm}  0.990955
# 12        {fob}             {key}  0.934261
# 11    {parasol}       {edwardian}  0.930624
# 10       {rack}            {coat}  0.828811
# 9       {charm}  {rustic, ribbon}  0.775157
# 8       {charm}          {ribbon}  0.775157
# 7       {charm}          {rustic}  0.775157
# 6   {edwardian}         {parasol}  0.772204
# 5        {rack}         {gumball}  0.702842
# 4         {key}             {fob}  0.570888
# 3      {ribbon}            {reel}  0.567373
# 1      {ribbon}          {rustic}  0.208898
# 2      {ribbon}   {rustic, charm}  0.208898
# 0      {ribbon}           {charm}  0.208898

# %%
noun30_2, adj30_2, clust30_2, rules30_2_df = get_cluster_properties(clusters30,2,0.03,0.03)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun30_2
# Out:
# {'set': 8993,
#  'retrospot': 3142,
#  'vintage': 3070,
#  'cutter': 2575,
#  'paper': 2363,
#  'cookie': 2335,
#  'heart': 2284,
#  'tea': 2146,
#  'pantry': 1888,
#  'piece': 1799,
#  'spaceboy': 1794,
#  'pencil': 1539,
#  'stationery': 1524,
#  'case': 1385,
#  'design': 1267,
#  'tlights': 1217,
#  'london': 1198,
#  'christmas': 1198,
#  'colour': 1187,
#  'jam': 1182}

# %%
adj30_2
# Out:
# {'wooden': 1530,
#  'ceramic': 1080,
#  'floral': 821,
#  'skittle': 608,
#  'white': 597,
#  'english': 588,
#  'napkin': 534,
#  'girl': 523,
#  'pink': 515,
#  'black': 487,
#  'retrospot': 462,
#  'soldier': 455,
#  'modern': 400,
#  'light': 393,
#  'tea': 389,
#  'colour': 376,
#  'retro': 367,
#  'teatime': 339,
#  'lucky': 260,
#  'traditional': 244}

# %%
rules30_2_df
# Out:
#                     0                       1         2
# 108    {set, printed}           {making, jam}  0.996627
# 107         {printed}      {making, set, jam}  0.996627
# 106    {set, printed}                {making}  0.996627
# 105         {printed}           {making, set}  0.996627
# 104         {printed}           {making, jam}  0.996627
# 103    {set, printed}                   {jam}  0.996627
# 102         {printed}              {set, jam}  0.996627
# 101         {printed}                {making}  0.996627
# 100         {printed}                   {jam}  0.996627
# 99          {vintage}                   {set}  0.992182
# 98              {tea}                   {set}  0.986318
# 97           {napkin}                   {set}  0.980598
# 96           {baking}                   {set}  0.941570
# 95             {mini}                   {set}  0.924384
# 94   {set, christmas}               {vintage}  0.909015
# 93        {christmas}          {set, vintage}  0.909015
# 92        {christmas}               {vintage}  0.909015
# 91      {cutter, set}                {cookie}  0.906796
# 90           {cutter}           {cookie, set}  0.906796
# 89           {cutter}                {cookie}  0.906796
# 88        {case, set}                {baking}  0.879422
# 87             {case}           {baking, set}  0.879422
# 86             {case}                {baking}  0.879422
# 81            {mould}                 {jelly}  0.870008
# 79            {mould}                {pantry}  0.870008
# 80            {mould}                   {set}  0.870008
# 82            {mould}           {pantry, set}  0.870008
# 83            {mould}         {pantry, jelly}  0.870008
# 84            {mould}            {jelly, set}  0.870008
# 85            {mould}    {pantry, jelly, set}  0.870008
# ..                ...                     ...       ...
# 29              {set}                {wooden}  0.044138
# 28              {set}                {colour}  0.043913
# 27              {set}                {pencil}  0.043239
# 26              {set}            {stationery}  0.042817
# 25              {set}                  {case}  0.038912
# 24              {set}                  {love}  0.036187
# 23              {set}                {design}  0.035597
# 22              {set}          {case, baking}  0.034220
# 21              {set}               {tlights}  0.034192
# 20              {set}                {napkin}  0.034080
# 19              {set}             {christmas}  0.033658
# 18              {set}        {colour, pencil}  0.033349
# 17              {set}               {printed}  0.033321
# 15              {set}       {making, printed}  0.033209
# 13              {set}          {printed, jam}  0.033209
# 11              {set}                   {jam}  0.033209
# 12              {set}                {making}  0.033209
# 16              {set}  {making, printed, jam}  0.033209
# 14              {set}           {making, jam}  0.033209
# 10              {set}                   {kid}  0.032001
# 4               {set}                 {mould}  0.031214
# 9               {set}  {mould, pantry, jelly}  0.031214
# 8               {set}          {mould, jelly}  0.031214
# 7               {set}         {pantry, jelly}  0.031214
# 6               {set}         {pantry, mould}  0.031214
# 5               {set}                 {jelly}  0.031214
# 3               {set}      {piece, retrospot}  0.030821
# 2               {set}    {vintage, christmas}  0.030596
# 1               {set}                 {chalk}  0.030568
# 0               {set}                  {mini}  0.030568
#
# [109 rows x 3 columns]

# %%
noun30_1, adj30_1, clust30_1, rules30_1_df = get_cluster_properties(clusters30,1,0.03,0.03)
# Out:
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\g1238\AppData\Local\conda\conda\envs\DL4Denv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
noun30_1
# Out:
# {'bag': 32274,
#  'vintage': 8281,
#  'paisley': 5829,
#  'lunch': 5003,
#  'polkadot': 3165,
#  'woodland': 2982,
#  'charlotte': 2862,
#  'pink': 2749,
#  'strawberry': 2271,
#  'retrospot': 2231,
#  'storage': 1934,
#  'blue': 1872,
#  'shopper': 1461,
#  'alphabet': 1388,
#  'shoulder': 1260,
#  'christmas': 1235,
#  'suki': 1214,
#  'car': 1197,
#  'picnic': 1143,
#  'airline': 1096}

# %%
adj30_1
# Out:
# {'jumbo': 19983,
#  'scandinavian': 1320,
#  'shopper': 1202,
#  'white': 1086,
#  'black': 960,
#  'marble': 702,
#  'red': 677,
#  'suki': 532,
#  'blue': 445,
#  'skull': 413,
#  'floral': 311,
#  'cosmetic': 189,
#  'overnight': 186,
#  'sud': 119,
#  'du': 119,
#  'soft': 103,
#  'brown': 97,
#  'circular': 60,
#  'metalic': 37,
#  'paperweight': 33}

# %%
rules30_1_df
# Out:
#                            0                          1         2
# 379  {scandinavian, paisley}                      {bag}  0.969697
# 378           {scandinavian}             {bag, paisley}  0.969697
# 377           {scandinavian}                      {bag}  0.969697
# 372         {bag, retrospot}                      {red}  0.967727
# 368              {retrospot}                    {jumbo}  0.967727
# 369              {retrospot}                      {red}  0.967727
# 370              {retrospot}               {jumbo, red}  0.967727
# 371              {retrospot}                 {bag, red}  0.967727
# 373              {retrospot}               {bag, jumbo}  0.967727
# 374         {bag, retrospot}                    {jumbo}  0.967727
# 375              {retrospot}          {bag, jumbo, red}  0.967727
# 376         {bag, retrospot}               {jumbo, red}  0.967727
# 367     {pink, bag, vintage}                  {paisley}  0.931721
# 366          {pink, vintage}             {bag, paisley}  0.931721
# 365          {pink, vintage}                  {paisley}  0.931721
# 364                   {blue}                      {bag}  0.918861
# 360           {red, paisley}         {shopper, vintage}  0.899701
# 357           {red, paisley}                    {jumbo}  0.899701
# 359           {red, paisley}                  {shopper}  0.899701
# 358           {red, paisley}                  {vintage}  0.899701
# 361           {red, paisley}           {jumbo, vintage}  0.899701
# 362           {red, paisley}           {shopper, jumbo}  0.899701
# 363           {red, paisley}  {shopper, jumbo, vintage}  0.899701
# 356                  {jumbo}                      {bag}  0.891458
# 355        {bag, jumbo, red}                {retrospot}  0.889209
# 354    {jumbo, vintage, red}         {shopper, paisley}  0.817131
# 353    {jumbo, vintage, red}                  {shopper}  0.817131
# 352    {jumbo, red, vintage}                  {paisley}  0.817131
# 351                {shopper}                    {jumbo}  0.814495
# 350                    {red}                    {jumbo}  0.814266
# ..                       ...                        ...       ...
# 29                     {bag}                     {suki}  0.054099
# 28                     {bag}         {vintage, paisley}  0.053325
# 27                     {bag}            {pink, vintage}  0.043564
# 26                     {bag}                 {alphabet}  0.043007
# 25                     {bag}   {pink, vintage, paisley}  0.040590
# 24                     {bag}            {pink, paisley}  0.040590
# 23                     {bag}    {scandinavian, paisley}  0.039660
# 22                     {bag}             {scandinavian}  0.039660
# 21                     {bag}                 {shoulder}  0.039041
# 20                     {bag}    {pink, polkadot, jumbo}  0.038762
# 19                     {bag}          {polkadot, jumbo}  0.038762
# 18                     {bag}         {jumbo, christmas}  0.038266
# 17                     {bag}                {christmas}  0.038266
# 14                     {bag}            {suki, storage}  0.037615
# 15                     {bag}              {suki, jumbo}  0.037615
# 16                     {bag}     {suki, jumbo, storage}  0.037615
# 13                     {bag}         {lunch, car, blue}  0.037089
# 12                     {bag}               {lunch, car}  0.037089
# 11                     {bag}              {lunch, blue}  0.037089
# 10                     {bag}                {car, blue}  0.037089
# 9                      {bag}                      {car}  0.037089
# 8                      {bag}                   {picnic}  0.035416
# 7                      {bag}    {pink, lunch, polkadot}  0.035230
# 6                      {bag}              {pink, lunch}  0.035230
# 5                      {bag}          {lunch, polkadot}  0.035230
# 4                      {bag}                    {skull}  0.035106
# 2                      {bag}                  {airline}  0.033959
# 3                      {bag}         {airline, vintage}  0.033959
# 1                      {bag}                    {white}  0.033649
# 0                      {bag}          {woodland, lunch}  0.032875
#
# [380 rows x 3 columns]
